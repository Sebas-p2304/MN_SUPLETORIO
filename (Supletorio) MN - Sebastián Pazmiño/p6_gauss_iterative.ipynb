# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]
x0=[0,0]
x1, tray1 = gauss_jacobi(A=A, b=b, x=x0, tol=1e-10, max_iter=1000)
print(x1)
print(tray1)
# Out:
# [02-12 15:37:10][INFO][sebas] 2026-02-12 15:37:10.791772
# [02-12 15:37:10][INFO][sebas] 2026-02-12 15:37:10.945861
# [02-12 15:37:10][INFO][sebas] 2026-02-12 15:37:10.945861
# [02-12 15:37:10][INFO][sebas] i= 0 x: [[0. 0.]]
# [[2.]
#  [1.]]
# [array([[0.],
#        [0.]]), array([[2.5],
#        [4. ]]), array([[0.5 ],
#        [0.25]]), array([[2.375],
#        [3.25 ]]), array([[0.875 ],
#        [0.4375]]), array([[2.28125],
#        [2.6875 ]]), array([[1.15625 ],
#        [0.578125]]), array([[2.2109375],
#        [2.265625 ]]), array([[1.3671875 ],
#        [0.68359375]]), array([[2.15820312],
#        [1.94921875]]), array([[1.52539062],
#        [0.76269531]]), array([[2.11865234],
#        [1.71191406]]), array([[1.64404297],
#        [0.82202148]]), array([[2.08898926],
#        [1.53393555]]), array([[1.73303223],
#        [0.86651611]]), array([[2.06674194],
#        [1.40045166]]), array([[1.79977417],
#        [0.89988708]]), array([[2.05005646],
#        [1.30033875]]), array([[1.84983063],
#        [0.92491531]]), array([[2.03754234],
#        [1.22525406]]), array([[1.88737297],
#        [0.94368649]]), array([[2.02815676],
#        [1.16894054]]), array([[1.91552973],
#        [0.95776486]]), array([[2.02111757],
#        [1.12670541]]), array([[1.9366473 ],
#        [0.96832365]]), array([[2.01583818],
#        [1.09502906]]), array([[1.95248547],
#        [0.97624274]]), array([[2.01187863],
#        [1.07127179]]), array([[1.9643641 ],
#        [0.98218205]]), array([[2.00890897],
#        [1.05345384]]), array([[1.97327308],
#        [0.98663654]]), array([[2.00668173],
#        [1.04009038]]), array([[1.97995481],
#        [0.9899774 ]]), array([[2.0050113 ],
#        [1.03006779]]), array([[1.98496611],
#        [0.99248305]]), array([[2.00375847],
#        [1.02255084]]), array([[1.98872458],
#        [0.99436229]]), array([[2.00281886],
#        [1.01691313]]), array([[1.99154343],
#        [0.99577172]]), array([[2.00211414],
#        [1.01268485]]), array([[1.99365758],
#        [0.99682879]]), array([[2.00158561],
#        [1.00951364]]), array([[1.99524318],
#        [0.99762159]]), array([[2.0011892 ],
#        [1.00713523]]), array([[1.99643239],
#        [0.99821619]]), array([[2.0008919 ],
#        [1.00535142]]), array([[1.99732429],
#        [0.99866214]]), array([[2.00066893],
#        [1.00401357]]), array([[1.99799322],
#        [0.99899661]]), array([[2.0005017 ],
#        [1.00301017]]), array([[1.99849491],
#        [0.99924746]]), array([[2.00037627],
#        [1.00225763]]), array([[1.99887118],
#        [0.99943559]]), array([[2.0002822 ],
#        [1.00169322]]), array([[1.99915339],
#        [0.99957669]]), array([[2.00021165],
#        [1.00126992]]), array([[1.99936504],
#        [0.99968252]]), array([[2.00015874],
#        [1.00095244]]), array([[1.99952378],
#        [0.99976189]]), array([[2.00011905],
#        [1.00071433]]), array([[1.99964284],
#        [0.99982142]]), array([[2.00008929],
#        [1.00053575]]), array([[1.99973213],
#        [0.99986606]]), array([[2.00006697],
#        [1.00040181]]), array([[1.9997991 ],
#        [0.99989955]]), array([[2.00005023],
#        [1.00030136]]), array([[1.99984932],
#        [0.99992466]]), array([[2.00003767],
#        [1.00022602]]), array([[1.99988699],
#        [0.9999435 ]]), array([[2.00002825],
#        [1.00016951]]), array([[1.99991524],
#        [0.99995762]]), array([[2.00002119],
#        [1.00012714]]), array([[1.99993643],
#        [0.99996822]]), array([[2.00001589],
#        [1.00009535]]), array([[1.99995232],
#        [0.99997616]]), array([[2.00001192],
#        [1.00007151]]), array([[1.99996424],
#        [0.99998212]]), array([[2.00000894],
#        [1.00005364]]), array([[1.99997318],
#        [0.99998659]]), array([[2.0000067 ],
#        [1.00004023]]), array([[1.99997989],
#        [0.99998994]]), array([[2.00000503],
#        [1.00003017]]), array([[1.99998492],
#        [0.99999246]]), array([[2.00000377],
#        [1.00002263]]), array([[1.99998869],
#        [0.99999434]]), array([[2.00000283],
#        [1.00001697]]), array([[1.99999151],
#        [0.99999576]]), array([[2.00000212],
#        [1.00001273]]), array([[1.99999364],
#        [0.99999682]]), array([[2.00000159],
#        [1.00000955]]), array([[1.99999523],
#        [0.99999761]]), array([[2.00000119],
#        [1.00000716]]), array([[1.99999642],
#        [0.99999821]]), array([[2.00000089],
#        [1.00000537]]), array([[1.99999732],
#        [0.99999866]]), array([[2.00000067],
#        [1.00000403]]), array([[1.99999799],
#        [0.99999899]]), array([[2.0000005 ],
#        [1.00000302]]), array([[1.99999849],
#        [0.99999924]]), array([[2.00000038],
#        [1.00000227]]), array([[1.99999887],
#        [0.99999943]]), array([[2.00000028],
#        [1.0000017 ]]), array([[1.99999915],
#        [0.99999958]]), array([[2.00000021],
#        [1.00000127]]), array([[1.99999936],
#        [0.99999968]]), array([[2.00000016],
#        [1.00000096]]), array([[1.99999952],
#        [0.99999976]]), array([[2.00000012],
#        [1.00000072]]), array([[1.99999964],
#        [0.99999982]]), array([[2.00000009],
#        [1.00000054]]), array([[1.99999973],
#        [0.99999987]]), array([[2.00000007],
#        [1.0000004 ]]), array([[1.9999998],
#        [0.9999999]]), array([[2.00000005],
#        [1.0000003 ]]), array([[1.99999985],
#        [0.99999992]]), array([[2.00000004],
#        [1.00000023]]), array([[1.99999989],
#        [0.99999994]]), array([[2.00000003],
#        [1.00000017]]), array([[1.99999991],
#        [0.99999996]]), array([[2.00000002],
#        [1.00000013]]), array([[1.99999994],
#        [0.99999997]]), array([[2.00000002],
#        [1.0000001 ]]), array([[1.99999995],
#        [0.99999998]]), array([[2.00000001],
#        [1.00000007]]), array([[1.99999996],
#        [0.99999998]]), array([[2.00000001],
#        [1.00000005]]), array([[1.99999997],
#        [0.99999999]]), array([[2.00000001],
#        [1.00000004]]), array([[1.99999998],
#        [0.99999999]]), array([[2.00000001],
#        [1.00000003]]), array([[1.99999998],
#        [0.99999999]]), array([[2.        ],
#        [1.00000002]]), array([[1.99999999],
#        [0.99999999]]), array([[2.        ],
#        [1.00000002]]), array([[1.99999999],
#        [1.        ]]), array([[2.        ],
#        [1.00000001]]), array([[1.99999999],
#        [1.        ]]), array([[2.        ],
#        [1.00000001]]), array([[2.],
#        [1.]]), array([[2.        ],
#        [1.00000001]]), array([[2.],
#        [1.]]), array([[2.        ],
#        [1.00000001]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]]), array([[2.],
#        [1.]])]

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[1,1],[-2,1]]
b = [6,0]
x0=[0,0]
x2, tray2 = gauss_seidel(A=A, b=b, x=x0)
print(x2)
print (tray2)
# Out:
# [02-12 15:37:14][INFO][sebas] i= 0 x: [[0. 0.]]
# [02-12 15:37:14][INFO][sebas] i= 1 x: [[ 6. 12.]]
# [02-12 15:37:14][INFO][sebas] i= 2 x: [[ -6. -12.]]
# [02-12 15:37:14][INFO][sebas] i= 3 x: [[18. 36.]]
# [02-12 15:37:14][INFO][sebas] i= 4 x: [[-30. -60.]]
# [02-12 15:37:14][INFO][sebas] i= 5 x: [[ 66. 132.]]
# [[ 66.]
#  [132.]]
# [array([[0.],
#        [0.]]), array([[ 6.],
#        [12.]]), array([[ -6.],
#        [-12.]]), array([[18.],
#        [36.]]), array([[-30.],
#        [-60.]]), array([[ 66.],
#        [132.]])]

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [p[0] for p in tray1]
y_values = [p[1] for p in tray1]


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria Ej1")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [p[0] for p in tray2]
y_values = [p[1] for p in tray2]


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria Ej2")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
