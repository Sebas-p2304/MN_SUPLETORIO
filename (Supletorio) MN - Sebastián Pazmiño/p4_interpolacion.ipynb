# %%
# Derivadas parciales para regresión grado 4
# ####################################################################

def der_par_4(xs: list, ys: list) -> tuple[float, float, float]:
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += yi * xi**4

        c_4 += xi ** 8

        c_3 += xi**7

        c_2 += xi**6

        # coeficiente del parámetro 1
        c_1 += xi ** 5

        # coeficiente del parámetro 0
        c_0 += xi**4

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_par_3(xs: list, ys: list) -> tuple[float, float, float]:
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += yi * xi**3

        c_4 += xi ** 7

        c_3 += xi**6

        c_2 += xi**5

        # coeficiente del parámetro 1
        c_1 += xi ** 4

        # coeficiente del parámetro 0
        c_0 += xi**3

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_par_2(xs: list, ys: list) -> tuple[float, float, float]:
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += yi * xi**2

        c_4 += xi ** 6

        c_3 += xi**5

        c_2 += xi**4

        # coeficiente del parámetro 1
        c_1 += xi ** 3

        # coeficiente del parámetro 0
        c_0 += xi**2

    return (c_4, c_3, c_2, c_1, c_0, c_ind)


def der_par_1(xs: list, ys: list) -> tuple[float, float, float]:
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += yi * xi

        c_4 += xi ** 5

        c_3 += xi**4

        c_2 += xi**3

        # coeficiente del parámetro 1
        c_1 += xi ** 2

        # coeficiente del parámetro 0
        c_0 += xi
    return (c_4, c_3, c_2, c_1, c_0, c_ind)


def der_par_0(xs: list, ys: list) -> tuple[float, float, float]:
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += yi 

        c_4 += xi ** 4

        c_3 += xi**3

        c_2 += xi**2

        # coeficiente del parámetro 1
        c_1 += xi

        # coeficiente del parámetro 0
        c_0 += 1
        

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
# Reemplace con el conjunto de datos dado
# --- Datos de ejemplo
import numpy as np
data = [(4.1,5.4), (3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1), (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), 
        (4.2,5.4), (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7), (2.4,5.2), (4.7,5.5), (8.8,6.0), 
        (5.2,5.5), (5.6,5.7), (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9), (0.6,5.0), (2.3,5.3), 
        (8.4,5.6), (0.4,5.1), (1.6,5.1), (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1), (5.5,5.5), 
        (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5), (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5), 
        (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4), (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), 
        (8.9,5.9), (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5), (8.9,5.9), (0.7,5.1), (5.8,5.6), 
        (6.2,5.7), (2.4,5.3), (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4), (3.1,5.3), (1.3,5.1), 
        (2.0,5.3), (-200.0,500), (0.4,5.1), (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2), (2.2,5.4), 
        (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6), (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5), 
        (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1), (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), 
        (2.0,5.2), (9.4,6.0)]
xs = [p[0] for p in data]
ys = [p[1] for p in data]
print(min(xs), max(xs))
# Out:
# -200.0 9.8

# %%
from src import ajustar_min_cuadrados
print (ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_1, der_parcial_0]))
# Out:
# [02-12 15:35:38][INFO][sebas] Se ajustarán 2 parámetros.
# [02-12 15:35:38][INFO][sebas]
# [[ 2.43400000e+02  1.01000000e+02  1.04540000e+03]
#  [ 0.00000000e+00 -1.75257200e+04 -2.81415359e+05]]
# [-2.36805702 16.05727801]

# %%
# Reemplace con la función obtenida de ajustar_min_cuadrados
interpolacion = lambda x: -2.36805702 * x + 16.05727801
# --- Función de ejemplo


import matplotlib.pyplot as plt

import numpy as np


# Dibujar los puntos x, y
plt.scatter(xs, ys, alpha=1, label="Datos")

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs), max(xs), 100)
y_aprox = [interpolacion(xi) for xi in x_aprox]
plt.plot(x_aprox, y_aprox, "r-", label="Interpolación: y = ")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Reemplace con la función obtenida de ajustar_min_cuadrados
interpolacion = lambda x: 0.09993919 * x + 5.01086963
# --- Función de ejemplo


import matplotlib.pyplot as plt

import numpy as np

# Dibujar los puntos x, y
plt.scatter(xs, ys, alpha=1, label="Datos")

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs), max(xs), 100)
y_aprox = [interpolacion(xi) for xi in x_aprox]
plt.plot(x_aprox, y_aprox, "r-", label="Interpolación: y = ")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_sinOut = [(4.1,5.4), (3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1), (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), 
        (4.2,5.4), (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7), (2.4,5.2), (4.7,5.5), (8.8,6.0), 
        (5.2,5.5), (5.6,5.7), (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9), (0.6,5.0), (2.3,5.3), 
        (8.4,5.6), (0.4,5.1), (1.6,5.1), (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1), (5.5,5.5), 
        (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5), (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5), 
        (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4), (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), 
        (8.9,5.9), (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5), (8.9,5.9), (0.7,5.1), (5.8,5.6), 
        (6.2,5.7), (2.4,5.3), (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4), (3.1,5.3), (1.3,5.1), 
        (2.0,5.3), (0.4,5.1), (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2), (2.2,5.4), 
        (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6), (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5), 
        (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1), (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), 
        (2.0,5.2), (9.4,6.0)]
xs1 = [p[0] for p in data_sinOut]
ys1 = [p[1] for p in data_sinOut]

# %%
from src import ajustar_min_cuadrados
print(ajustar_min_cuadrados(xs1, ys1, gradiente=[der_par_4, der_par_3, der_par_2, der_par_1, der_par_0]))
print("Valores de x**4, x**3 y x**2 insignificantes")
# Out:
# [02-12 15:36:42][INFO][sebas] Se ajustarán 5 parámetros.
# [02-12 15:36:42][INFO][sebas]
# [[ 1.66563525e+05  2.08531260e+04  2.82182000e+03  4.43400000e+02
#    1.00000000e+02  5.45400000e+02]
#  [ 0.00000000e+00 -1.19087888e+06 -3.91136106e+05 -1.13767312e+05
#   -4.23698864e+04 -2.23645385e+05]
#  [ 0.00000000e+00 -1.08586894e+05 -3.66163550e+04 -1.10730630e+04
#   -4.37849326e+03 -2.30445055e+04]
#  [ 0.00000000e+00 -7.82274818e+03 -2.74461528e+03 -8.86155166e+02
#   -3.92859623e+02 -2.05712998e+03]
#  [ 0.00000000e+00 -1.20688835e+07 -3.88999756e+06 -1.10284870e+06
#   -3.96303459e+05 -2.09559028e+06]]
# [02-12 15:36:42][INFO][sebas]
# [[ 1.66563525e+05  2.08531260e+04  2.82182000e+03  4.43400000e+02
#    1.00000000e+02  5.45400000e+02]
#  [ 0.00000000e+00 -7.82274818e+03 -2.74461528e+03 -8.86155166e+02
#   -3.92859623e+02 -2.05712998e+03]
#  [ 0.00000000e+00  0.00000000e+00  1.48141350e+03  1.22758061e+03
#    1.07475735e+03  5.51033872e+03]
# ...

# %%
interpolacion = lambda x: 0.09993919 * x + 5.01086963


import matplotlib.pyplot as plt

import numpy as np

# Dibujar los puntos x, y
plt.scatter(xs1, ys1, alpha=1, label="Datos")

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs1), max(xs1), 100)
y_aprox = [interpolacion(xi) for xi in x_aprox]
plt.plot(x_aprox, y_aprox, "r-", label="Interpolación: y = ")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Datos sin outlier")
plt.legend()
plt.grid(True)
plt.show()

# %%
avgErr = sum(abs((interpolacion(xi) - yi)/yi) for xi, yi in zip(xs1, ys1))/len(xs1)
maxErr = max(abs((interpolacion(xi) - yi)/yi) for xi, yi in zip(xs1, ys1))
print("Error relativo promedio: ", avgErr)
print("Error relativo maximo:", maxErr)
# Out:
# Error relativo promedio:  0.014186571299409529
# Error relativo maximo: 0.04506178346938771
